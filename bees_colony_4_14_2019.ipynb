# %% [markdown]
# # Save the bees.
#
# ### https://data.world/finley/bee-colony-statistical-data-from-1987-2017
# ### https://usda.library.cornell.edu/concern/publications/rn301137d?locale=en

# %% [markdown]
# ###Glossary
# https://github.com/cocoisland/python_apps/blob/master/bees/finley-bee-colony-statistical-data-from-1987-2017/glossary%20for%20bee%20stats.pdf
#
# ###Survey png
# https://github.com/cocoisland/python_apps/blob/master/bees/finley-bee-colony-statistical-data-from-1987-2017/Search%20criteria%20for%20bee%20colony%20survey.png
#
# ###Census png
# https://github.com/cocoisland/python_apps/blob/master/bees/finley-bee-colony-statistical-data-from-1987-2017/Search%20criteria%20for%20bee%20colony%20census.png

# %%
import pandas as pd

df_county = pd.read_csv('https://raw.githubusercontent.com/cocoisland/python_apps/master/bees/finley-bee-colony-statistical-data-from-1987-2017/Bee%20Colony%20Census%20Data%20by%20County.csv')
#df_loss = pd.read_excel('finley-bee-colony-statistical-data-from-1987-2017/Bee Colony Loss.xlsx', sheet_name='Sheet1') 
df_loss = pd.read_csv('https://raw.githubusercontent.com/cocoisland/python_apps/master/bees/Bee%20Colony%20Loss.csv')
df_state = pd.read_csv('https://raw.githubusercontent.com/cocoisland/python_apps/master/bees/finley-bee-colony-statistical-data-from-1987-2017/Bee%20Colony%20Survey%20Data%20by%20State.csv')

df_county.shape,  df_state.shape, df_loss.shape
# Out:
# ((7830, 10), (3396, 9), (365, 8))

# %%
df_loss.head()
# Out:
#       Year  Season          State Total Annual Loss  Beekeepers  \
# 0  2016/17  Annual  Massachusetts            15.90%          87
# 1  2016/17  Annual        Montana            17.10%          21
# 2  2016/17  Annual         Nevada            23.00%          13
# 3  2016/17  Annual          Maine            23.30%          65
# 4  2016/17  Annual        Wyoming            23.40%          18
#
#   Beekeepers Exclusive to State  Colonies Colonies Exclusive to State
# 0                        94.30%     27186                       2.30%
# 1                        52.40%     35905                       0.30%
# 2                        92.30%      2512                       5.20%
# 3                        93.80%     41102                       1.40%
# 4                        77.80%      6521                       1.40%

# %%
# Convert camel case State to upper case to be the same as upper case State in df_state
df_loss['State']=df_loss['State'].str.upper()

# %%
# convert 2016/17 to 2016 to match Year in df_state
df_loss['Year']=df_loss.Year.str[:-3]

# %%
df_state.head()
# Out:
#    Year        Period  Week Ending       State  State ANSI  Watershed  \
# 0  2017  JAN THRU MAR          NaN     ALABAMA           1        NaN
# 1  2017  JAN THRU MAR          NaN     ARIZONA           4        NaN
# 2  2017  JAN THRU MAR          NaN    ARKANSAS           5        NaN
# 3  2017  JAN THRU MAR          NaN  CALIFORNIA           6        NaN
# 4  2017  JAN THRU MAR          NaN    COLORADO           8        NaN
#
#           Data Item    Value  CV (%)
# 0  ADDED & REPLACED      570     NaN
# 1  ADDED & REPLACED    2,900     NaN
# 2  ADDED & REPLACED      430     NaN
# 3  ADDED & REPLACED  215,000     NaN
# 4  ADDED & REPLACED      100     NaN

# %%
df_state.dtypes
# Out:
# Year             int64
# Period          object
# Week Ending    float64
# State           object
# State ANSI       int64
# Watershed      float64
# Data Item       object
# Value           object
# CV (%)         float64
# dtype: object

# %%
# convert Value object to float
df_state['Value'] = df_state.Value.str.replace(',','').astype(float)

# %%
# convert df_state Year int64 to object type, so that to match df_loss Year type.
df_state['Year'] = df_state.Year.astype(object)

# %% [markdown]
# df_state value represents Agriculture value which might have relationship to bees colony.
#
# Hence the intention to sum up total Agriculture value per State-Year and add into df_loss table.

# %%
# take ALABAMA as example to sum up value for year 2015
df_state.loc[(df_state['Year'] == 2015) & (df_state['State']=='ALABAMA')]
# Out:
#       Year          Period  Week Ending    State  State ANSI  Watershed  \
# 270   2015    JAN THRU MAR          NaN  ALABAMA           1        NaN
# 315   2015    APR THRU JUN          NaN  ALABAMA           1        NaN
# 360   2015    JUL THRU SEP          NaN  ALABAMA           1        NaN
# 405   2015    OCT THRU DEC          NaN  ALABAMA           1        NaN
# 720   2015    JAN THRU MAR          NaN  ALABAMA           1        NaN
# 765   2015    APR THRU JUN          NaN  ALABAMA           1        NaN
# 810   2015    JUL THRU SEP          NaN  ALABAMA           1        NaN
# 855   2015    OCT THRU DEC          NaN  ALABAMA           1        NaN
# 1438  2015    JAN THRU MAR          NaN  ALABAMA           1        NaN
# 1483  2015    APR THRU JUN          NaN  ALABAMA           1        NaN
# 1528  2015    JUL THRU SEP          NaN  ALABAMA           1        NaN
# 1573  2015    OCT THRU DEC          NaN  ALABAMA           1        NaN
# 1968  2015  MARKETING YEAR          NaN  ALABAMA           1        NaN
# 2008  2015    FIRST OF JAN          NaN  ALABAMA           1        NaN
# 2053  2015    FIRST OF APR          NaN  ALABAMA           1        NaN
# 2098  2015    FIRST OF JUL          NaN  ALABAMA           1        NaN
# 2143  2015    FIRST OF OCT          NaN  ALABAMA           1        NaN
#
#              Data Item   Value  CV (%)
# 270   ADDED & REPLACED  2800.0     NaN
# 315   ADDED & REPLACED  1900.0     NaN
# 360   ADDED & REPLACED   160.0     NaN
# 405   ADDED & REPLACED    80.0     NaN
# 720     INVENTORY, MAX  7000.0     NaN
# 765     INVENTORY, MAX  7500.0     NaN
# 810     INVENTORY, MAX  9000.0     NaN
# 855     INVENTORY, MAX  8000.0     NaN
# 1438     LOSS, DEADOUT  1800.0     NaN
# 1483     LOSS, DEADOUT   860.0     NaN
# 1528     LOSS, DEADOUT  1400.0     NaN
# 1573     LOSS, DEADOUT   610.0     NaN
# 1968         INVENTORY  7000.0     NaN
# 2008         INVENTORY  7000.0     NaN
# 2053         INVENTORY  7500.0     NaN
# 2098         INVENTORY  8500.0     NaN
# 2143         INVENTORY  8000.0     NaN

# %%
# method 1 : summing up Value as subtotal. But we want total value for State-Year-Period
df_state.groupby(['State','Year','Period','Value']).sum().head(50)
# Out:
#                                      Week Ending  State ANSI  Watershed  \
# State   Year Period         Value
# ALABAMA 1987 MARKETING YEAR 46000.0          0.0           1        0.0
#         1988 MARKETING YEAR 42000.0          0.0           1        0.0
#         1989 MARKETING YEAR 41000.0          0.0           1        0.0
#         1990 MARKETING YEAR 29000.0          0.0           1        0.0
#         1991 MARKETING YEAR 23000.0          0.0           1        0.0
#         1992 MARKETING YEAR 25000.0          0.0           1        0.0
#         1993 MARKETING YEAR 19000.0          0.0           1        0.0
#         1994 MARKETING YEAR 18000.0          0.0           1        0.0
#         1995 MARKETING YEAR 16000.0          0.0           1        0.0
#         1996 MARKETING YEAR 15000.0          0.0           1        0.0
#         1997 MARKETING YEAR 14000.0          0.0           1        0.0
#         1998 MARKETING YEAR 16000.0          0.0           1        0.0
#         1999 MARKETING YEAR 17000.0          0.0           1        0.0
#         2000 MARKETING YEAR 16000.0          0.0           1        0.0
#         2001 MARKETING YEAR 14000.0          0.0           1        0.0
#         2002 MARKETING YEAR 12000.0          0.0           1        0.0
#         2003 MARKETING YEAR 13000.0          0.0           1        0.0
#         2004 MARKETING YEAR 12000.0          0.0           1        0.0
#         2005 MARKETING YEAR 13000.0          0.0           1        0.0
#         2006 MARKETING YEAR 11000.0          0.0           1        0.0
#         2007 MARKETING YEAR 11000.0          0.0           1        0.0
#         2008 MARKETING YEAR 9000.0           0.0           1        0.0
#         2009 MARKETING YEAR 9000.0           0.0           1        0.0
#         2010 MARKETING YEAR 9000.0           0.0           1        0.0
#         2011 MARKETING YEAR 9000.0           0.0           1        0.0
#         2012 MARKETING YEAR 8000.0           0.0           1        0.0
#         2013 MARKETING YEAR 7000.0           0.0           1        0.0
#         2014 MARKETING YEAR 7000.0           0.0           1        0.0
#         2015 APR THRU JUN   860.0            0.0           1        0.0
#                             1900.0           0.0           1        0.0
#                             7500.0           0.0           1        0.0
#              FIRST OF APR   7500.0           0.0           1        0.0
#              FIRST OF JAN   7000.0           0.0           1        0.0
#              FIRST OF JUL   8500.0           0.0           1        0.0
#              FIRST OF OCT   8000.0           0.0           1        0.0
#              JAN THRU MAR   1800.0           0.0           1        0.0
#                             2800.0           0.0           1        0.0
#                             7000.0           0.0           1        0.0
#              JUL THRU SEP   160.0            0.0           1        0.0
#                             1400.0           0.0           1        0.0
#                             9000.0           0.0           1        0.0
#              MARKETING YEAR 7000.0           0.0           1        0.0
#              OCT THRU DEC   80.0             0.0           1        0.0
#                             610.0            0.0           1        0.0
#                             8000.0           0.0           1        0.0
#         2016 APR THRU JUN   130.0            0.0           1        0.0
#                             930.0            0.0           1        0.0
#                             1200.0           0.0           1        0.0
#                             8000.0           0.0           1        0.0
#              FIRST OF APR   8000.0           0.0           1        0.0
#
#                                      CV (%)
# State   Year Period         Value
# ALABAMA 1987 MARKETING YEAR 46000.0     0.0
#         1988 MARKETING YEAR 42000.0     0.0
#         1989 MARKETING YEAR 41000.0     0.0
#         1990 MARKETING YEAR 29000.0     0.0
#         1991 MARKETING YEAR 23000.0     0.0
#         1992 MARKETING YEAR 25000.0     0.0
#         1993 MARKETING YEAR 19000.0     0.0
#         1994 MARKETING YEAR 18000.0     0.0
#         1995 MARKETING YEAR 16000.0     0.0
#         1996 MARKETING YEAR 15000.0     0.0
#         1997 MARKETING YEAR 14000.0     0.0
#         1998 MARKETING YEAR 16000.0     0.0
#         1999 MARKETING YEAR 17000.0     0.0
#         2000 MARKETING YEAR 16000.0     0.0
#         2001 MARKETING YEAR 14000.0     0.0
#         2002 MARKETING YEAR 12000.0     0.0
#         2003 MARKETING YEAR 13000.0     0.0
#         2004 MARKETING YEAR 12000.0     0.0
#         2005 MARKETING YEAR 13000.0     0.0
#         2006 MARKETING YEAR 11000.0     0.0
#         2007 MARKETING YEAR 11000.0     0.0
#         2008 MARKETING YEAR 9000.0      0.0
#         2009 MARKETING YEAR 9000.0      0.0
#         2010 MARKETING YEAR 9000.0      0.0
#         2011 MARKETING YEAR 9000.0      0.0
#         2012 MARKETING YEAR 8000.0      0.0
#         2013 MARKETING YEAR 7000.0      0.0
#         2014 MARKETING YEAR 7000.0      0.0
#         2015 APR THRU JUN   860.0       0.0
#                             1900.0      0.0
#                             7500.0      0.0
#              FIRST OF APR   7500.0      0.0
#              FIRST OF JAN   7000.0      0.0
#              FIRST OF JUL   8500.0      0.0
#              FIRST OF OCT   8000.0      0.0
#              JAN THRU MAR   1800.0      0.0
#                             2800.0      0.0
#                             7000.0      0.0
#              JUL THRU SEP   160.0       0.0
#                             1400.0      0.0
#                             9000.0      0.0
#              MARKETING YEAR 7000.0      0.0
#              OCT THRU DEC   80.0        0.0
#                             610.0       0.0
#                             8000.0      0.0
#         2016 APR THRU JUN   130.0       0.0
#                             930.0       0.0
#                             1200.0      0.0
#                             8000.0      0.0
#              FIRST OF APR   8000.0      0.0

# %%
# method 2: summing value as total for State-Year-Period. But subtotal by Period
df_state.Value.groupby([df_state['State'],df_state['Year'],df_state['Period']]).sum().head(50)
# Out:
# State    Year  Period
# ALABAMA  1987  MARKETING YEAR    46000.0
#          1988  MARKETING YEAR    42000.0
#          1989  MARKETING YEAR    41000.0
#          1990  MARKETING YEAR    29000.0
#          1991  MARKETING YEAR    23000.0
#          1992  MARKETING YEAR    25000.0
#          1993  MARKETING YEAR    19000.0
#          1994  MARKETING YEAR    18000.0
#          1995  MARKETING YEAR    16000.0
#          1996  MARKETING YEAR    15000.0
#          1997  MARKETING YEAR    14000.0
#          1998  MARKETING YEAR    16000.0
#          1999  MARKETING YEAR    17000.0
#          2000  MARKETING YEAR    16000.0
#          2001  MARKETING YEAR    14000.0
#          2002  MARKETING YEAR    12000.0
#          2003  MARKETING YEAR    13000.0
#          2004  MARKETING YEAR    12000.0
#          2005  MARKETING YEAR    13000.0
#          2006  MARKETING YEAR    11000.0
#          2007  MARKETING YEAR    11000.0
#          2008  MARKETING YEAR     9000.0
#          2009  MARKETING YEAR     9000.0
#          2010  MARKETING YEAR     9000.0
#          2011  MARKETING YEAR     9000.0
#          2012  MARKETING YEAR     8000.0
#          2013  MARKETING YEAR     7000.0
#          2014  MARKETING YEAR     7000.0
#          2015  APR THRU JUN      10260.0
#                FIRST OF APR       7500.0
#                FIRST OF JAN       7000.0
#                FIRST OF JUL       8500.0
#                FIRST OF OCT       8000.0
#                JAN THRU MAR      11600.0
#                JUL THRU SEP      10560.0
#                MARKETING YEAR     7000.0
#                OCT THRU DEC       8690.0
#          2016  APR THRU JUN      10260.0
#                FIRST OF APR       8000.0
#                FIRST OF JAN       7500.0
#                FIRST OF JUL       8000.0
#                FIRST OF OCT       7000.0
#                JAN THRU MAR      11780.0
#                JUL THRU SEP      10040.0
#                MARKETING YEAR     7000.0
#                OCT THRU DEC       7760.0
#          2017  APR THRU JUN       8160.0
#                FIRST OF APR       6500.0
#                FIRST OF JAN       7000.0
#                JAN THRU MAR       9420.0
# Name: Value, dtype: float64

# %%
# summing ALABAMA state and Year 2015 to check method3 total accuracy
10260+7500+7000+8500+8000+11600+10560+7000+8690
# Out:
# 79110

# %%
# method 3: summing value as total for State-Year. Total by State-Year. 
dfs=df_state.Value.groupby([df_state['State'],df_state['Year']]).sum()

# %%
dfs=dfs.reset_index()

# %%
# Value per Alabama and 2015 = 79110.0 matched calculated above. Hence result checked out.
dfs.head(30)
# Out:
#       State  Year    Value
# 0   ALABAMA  1987  46000.0
# 1   ALABAMA  1988  42000.0
# 2   ALABAMA  1989  41000.0
# 3   ALABAMA  1990  29000.0
# 4   ALABAMA  1991  23000.0
# 5   ALABAMA  1992  25000.0
# 6   ALABAMA  1993  19000.0
# 7   ALABAMA  1994  18000.0
# 8   ALABAMA  1995  16000.0
# 9   ALABAMA  1996  15000.0
# 10  ALABAMA  1997  14000.0
# 11  ALABAMA  1998  16000.0
# 12  ALABAMA  1999  17000.0
# 13  ALABAMA  2000  16000.0
# 14  ALABAMA  2001  14000.0
# 15  ALABAMA  2002  12000.0
# 16  ALABAMA  2003  13000.0
# 17  ALABAMA  2004  12000.0
# 18  ALABAMA  2005  13000.0
# 19  ALABAMA  2006  11000.0
# 20  ALABAMA  2007  11000.0
# 21  ALABAMA  2008   9000.0
# 22  ALABAMA  2009   9000.0
# 23  ALABAMA  2010   9000.0
# 24  ALABAMA  2011   9000.0
# 25  ALABAMA  2012   8000.0
# 26  ALABAMA  2013   7000.0
# 27  ALABAMA  2014   7000.0
# 28  ALABAMA  2015  79110.0
# 29  ALABAMA  2016  77340.0

# %%
dfs.dtypes
# Out:
# State     object
# Year       int64
# Value    float64
# dtype: object

# %%
# convert Year int64 to object type, in order to match df_loss Year object type.
dfs['Year']=dfs.Year.astype(object)

# %%
dfx=pd.merge(df_loss, dfs, how='right',left_on=['State','Year'], right_on=['State','Year'])

# %%
dfx.loc[dfx['State']=='MONTANA']
# Out:
#      Year Season    State Total Annual Loss  Beekeepers  \
# 658  1987    NaN  MONTANA               NaN         NaN
# 659  1988    NaN  MONTANA               NaN         NaN
# 660  1989    NaN  MONTANA               NaN         NaN
# 661  1990    NaN  MONTANA               NaN         NaN
# 662  1991    NaN  MONTANA               NaN         NaN
# 663  1992    NaN  MONTANA               NaN         NaN
# 664  1993    NaN  MONTANA               NaN         NaN
# 665  1994    NaN  MONTANA               NaN         NaN
# 666  1995    NaN  MONTANA               NaN         NaN
# 667  1996    NaN  MONTANA               NaN         NaN
# 668  1997    NaN  MONTANA               NaN         NaN
# 669  1998    NaN  MONTANA               NaN         NaN
# 670  1999    NaN  MONTANA               NaN         NaN
# 671  2000    NaN  MONTANA               NaN         NaN
# 672  2001    NaN  MONTANA               NaN         NaN
# 673  2002    NaN  MONTANA               NaN         NaN
# 674  2003    NaN  MONTANA               NaN         NaN
# 675  2004    NaN  MONTANA               NaN         NaN
# 676  2005    NaN  MONTANA               NaN         NaN
# 677  2006    NaN  MONTANA               NaN         NaN
# 678  2007    NaN  MONTANA               NaN         NaN
# 679  2008    NaN  MONTANA               NaN         NaN
# 680  2009    NaN  MONTANA               NaN         NaN
# 681  2010    NaN  MONTANA               NaN         NaN
# 682  2011    NaN  MONTANA               NaN         NaN
# 683  2012    NaN  MONTANA               NaN         NaN
# 684  2013    NaN  MONTANA               NaN         NaN
# 685  2014    NaN  MONTANA               NaN         NaN
# 686  2015    NaN  MONTANA               NaN         NaN
# 687  2016    NaN  MONTANA               NaN         NaN
# 688  2017    NaN  MONTANA               NaN         NaN
#
#     Beekeepers Exclusive to State  Colonies Colonies Exclusive to State  \
# 658                           NaN       NaN                         NaN
# 659                           NaN       NaN                         NaN
# 660                           NaN       NaN                         NaN
# 661                           NaN       NaN                         NaN
# 662                           NaN       NaN                         NaN
# 663                           NaN       NaN                         NaN
# 664                           NaN       NaN                         NaN
# 665                           NaN       NaN                         NaN
# 666                           NaN       NaN                         NaN
# 667                           NaN       NaN                         NaN
# 668                           NaN       NaN                         NaN
# 669                           NaN       NaN                         NaN
# 670                           NaN       NaN                         NaN
# 671                           NaN       NaN                         NaN
# 672                           NaN       NaN                         NaN
# 673                           NaN       NaN                         NaN
# 674                           NaN       NaN                         NaN
# 675                           NaN       NaN                         NaN
# 676                           NaN       NaN                         NaN
# 677                           NaN       NaN                         NaN
# 678                           NaN       NaN                         NaN
# 679                           NaN       NaN                         NaN
# 680                           NaN       NaN                         NaN
# 681                           NaN       NaN                         NaN
# 682                           NaN       NaN                         NaN
# 683                           NaN       NaN                         NaN
# 684                           NaN       NaN                         NaN
# 685                           NaN       NaN                         NaN
# 686                           NaN       NaN                         NaN
# 687                           NaN       NaN                         NaN
# 688                           NaN       NaN                         NaN
#
#          Value
# 658    95000.0
# 659   105000.0
# 660   100000.0
# 661    98000.0
# 662    86000.0
# 663    87000.0
# 664    95000.0
# 665   119000.0
# 666   106000.0
# 667   117000.0
# 668   107000.0
# 669   115000.0
# 670   122000.0
# 671   124000.0
# 672   136000.0
# 673   134000.0
# 674   145000.0
# 675   140000.0
# 676   130000.0
# 677   132000.0
# 678   135000.0
# 679   134000.0
# 680   146000.0
# 681   157000.0
# 682   145000.0
# 683   145000.0
# 684   159000.0
# 685   162000.0
# 686  1018000.0
# 687  1108420.0
# 688   414870.0

# %%
dfx.head(20)
# Out:
#     Year Season    State Total Annual Loss  Beekeepers  \
# 0   1987    NaN  ALABAMA               NaN         NaN
# 1   1988    NaN  ALABAMA               NaN         NaN
# 2   1989    NaN  ALABAMA               NaN         NaN
# 3   1990    NaN  ALABAMA               NaN         NaN
# 4   1991    NaN  ALABAMA               NaN         NaN
# 5   1992    NaN  ALABAMA               NaN         NaN
# 6   1993    NaN  ALABAMA               NaN         NaN
# 7   1994    NaN  ALABAMA               NaN         NaN
# 8   1995    NaN  ALABAMA               NaN         NaN
# 9   1996    NaN  ALABAMA               NaN         NaN
# 10  1997    NaN  ALABAMA               NaN         NaN
# 11  1998    NaN  ALABAMA               NaN         NaN
# 12  1999    NaN  ALABAMA               NaN         NaN
# 13  2000    NaN  ALABAMA               NaN         NaN
# 14  2001    NaN  ALABAMA               NaN         NaN
# 15  2002    NaN  ALABAMA               NaN         NaN
# 16  2003    NaN  ALABAMA               NaN         NaN
# 17  2004    NaN  ALABAMA               NaN         NaN
# 18  2005    NaN  ALABAMA               NaN         NaN
# 19  2006    NaN  ALABAMA               NaN         NaN
#
#    Beekeepers Exclusive to State  Colonies Colonies Exclusive to State  \
# 0                            NaN       NaN                         NaN
# 1                            NaN       NaN                         NaN
# 2                            NaN       NaN                         NaN
# 3                            NaN       NaN                         NaN
# 4                            NaN       NaN                         NaN
# 5                            NaN       NaN                         NaN
# 6                            NaN       NaN                         NaN
# 7                            NaN       NaN                         NaN
# 8                            NaN       NaN                         NaN
# 9                            NaN       NaN                         NaN
# 10                           NaN       NaN                         NaN
# 11                           NaN       NaN                         NaN
# 12                           NaN       NaN                         NaN
# 13                           NaN       NaN                         NaN
# 14                           NaN       NaN                         NaN
# 15                           NaN       NaN                         NaN
# 16                           NaN       NaN                         NaN
# 17                           NaN       NaN                         NaN
# 18                           NaN       NaN                         NaN
# 19                           NaN       NaN                         NaN
#
#       Value
# 0   46000.0
# 1   42000.0
# 2   41000.0
# 3   29000.0
# 4   23000.0
# 5   25000.0
# 6   19000.0
# 7   18000.0
# 8   16000.0
# 9   15000.0
# 10  14000.0
# 11  16000.0
# 12  17000.0
# 13  16000.0
# 14  14000.0
# 15  12000.0
# 16  13000.0
# 17  12000.0
# 18  13000.0
# 19  11000.0

# %%
dfx.isna().sum()
# Out:
# Year                                0
# Season                           1343
# State                               0
# Total Annual Loss                1343
# Beekeepers                       1343
# Beekeepers Exclusive to State    1343
# Colonies                         1343
# Colonies Exclusive to State      1343
# Value                               0
# dtype: int64

# %%
dfx.shape
# Out:
# (1343, 9)

# %%
#lol what happened to this dataset...
df_state.isna().sum()
# Out:
# Year              0
# Period            0
# Week Ending    3396
# State             0
# State ANSI        0
# Watershed      3396
# Data Item         0
# Value             0
# CV (%)         3396
# dtype: int64

# %%
print(df_state.shape)
# Out:
# (3396, 9)

# %%
df['Data Ite']
